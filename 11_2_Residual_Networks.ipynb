# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# fatal: destination path 'mnist1d' already exists and is not an empty directory.

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 4000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# %%
# TODO -- Add residual connections to this model
# The order of operations within each block should similar 
# to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, 
# ReLU+linear3 in second residual block), linear4 at end
# Replace this function
def forward_old(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1).relu()
    h3 = self.linear3(h2).relu()
    return self.linear4(h3)

# %%
# TODO -- Add residual connections to this model
# The order of operations within each block should similar 
# to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, 
# ReLU+linear3 in second residual block), linear4 at end
# Replace this function
def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1).relu()
    h2 += h1
    h3 = self.linear3(h2).relu()
    h3 += h2
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.572066, train error 61.62,  val loss 1.639450, percent error 64.43
# Epoch     1, train loss 1.331264, train error 49.35,  val loss 1.481826, percent error 57.35
# Epoch     2, train loss 1.088157, train error 40.50,  val loss 1.333629, percent error 52.45
# Epoch     3, train loss 0.970397, train error 35.93,  val loss 1.268244, percent error 47.80
# Epoch     4, train loss 0.874373, train error 32.65,  val loss 1.263485, percent error 47.50
# Epoch     5, train loss 0.713803, train error 26.20,  val loss 1.194641, percent error 44.12
# Epoch     6, train loss 0.648096, train error 22.78,  val loss 1.211063, percent error 44.00
# Epoch     7, train loss 0.582808, train error 21.55,  val loss 1.186473, percent error 42.40
# Epoch     8, train loss 0.446708, train error 16.12,  val loss 1.198347, percent error 40.25
# Epoch     9, train loss 0.360573, train error 11.88,  val loss 1.156288, percent error 39.12
# Epoch    10, train loss 0.326073, train error 10.50,  val loss 1.257609, percent error 39.00
# Epoch    11, train loss 0.293063, train error 9.97,  val loss 1.298620, percent error 37.47
# Epoch    12, train loss 0.281060, train error 10.03,  val loss 1.341396, percent error 38.40
# Epoch    13, train loss 0.346868, train error 12.00,  val loss 1.505136, percent error 38.90
# Epoch    14, train loss 0.231435, train error 7.78,  val loss 1.426417, percent error 39.62
# Epoch    15, train loss 0.167101, train error 4.97,  val loss 1.439553, percent error 37.53
# Epoch    16, train loss 0.121635, train error 3.18,  val loss 1.462392, percent error 37.00
# Epoch    17, train loss 0.086744, train error 2.47,  val loss 1.553667, percent error 37.20
# Epoch    18, train loss 0.095070, train error 2.57,  val loss 1.622645, percent error 36.28
# Epoch    19, train loss 0.109858, train error 3.18,  val loss 1.701921, percent error 36.12
# Epoch    20, train loss 0.026890, train error 0.18,  val loss 1.591217, percent error 35.88
# Epoch    21, train loss 0.013425, train error 0.00,  val loss 1.575364, percent error 34.40
# Epoch    22, train loss 0.009351, train error 0.00,  val loss 1.605729, percent error 34.50
# Epoch    23, train loss 0.007801, train error 0.00,  val loss 1.632873, percent error 34.07
# Epoch    24, train loss 0.006804, train error 0.00,  val loss 1.653663, percent error 34.15
# Epoch    25, train loss 0.006080, train error 0.00,  val loss 1.675259, percent error 34.18
# Epoch    26, train loss 0.005544, train error 0.00,  val loss 1.692705, percent error 34.30
# Epoch    27, train loss 0.005077, train error 0.00,  val loss 1.708784, percent error 34.05
# Epoch    28, train loss 0.004697, train error 0.00,  val loss 1.724687, percent error 34.15
# Epoch    29, train loss 0.004374, train error 0.00,  val loss 1.738250, percent error 34.00
# Epoch    30, train loss 0.004094, train error 0.00,  val loss 1.751083, percent error 34.05
# Epoch    31, train loss 0.003871, train error 0.00,  val loss 1.763913, percent error 33.95
# Epoch    32, train loss 0.003654, train error 0.00,  val loss 1.776763, percent error 34.00
# Epoch    33, train loss 0.003458, train error 0.00,  val loss 1.787915, percent error 34.00
# Epoch    34, train loss 0.003291, train error 0.00,  val loss 1.797512, percent error 34.00
# Epoch    35, train loss 0.003154, train error 0.00,  val loss 1.809489, percent error 34.15
# Epoch    36, train loss 0.003001, train error 0.00,  val loss 1.819383, percent error 34.05
# Epoch    37, train loss 0.002879, train error 0.00,  val loss 1.830322, percent error 34.20
# Epoch    38, train loss 0.002764, train error 0.00,  val loss 1.836745, percent error 33.95
# Epoch    39, train loss 0.002657, train error 0.00,  val loss 1.846516, percent error 33.95
# Epoch    40, train loss 0.002599, train error 0.00,  val loss 1.850164, percent error 33.90
# Epoch    41, train loss 0.002552, train error 0.00,  val loss 1.853791, percent error 33.93
# Epoch    42, train loss 0.002506, train error 0.00,  val loss 1.858186, percent error 33.90
# Epoch    43, train loss 0.002464, train error 0.00,  val loss 1.861732, percent error 33.82
# Epoch    44, train loss 0.002420, train error 0.00,  val loss 1.865567, percent error 33.80
# Epoch    45, train loss 0.002380, train error 0.00,  val loss 1.869752, percent error 33.85
# Epoch    46, train loss 0.002340, train error 0.00,  val loss 1.873896, percent error 33.95
# Epoch    47, train loss 0.002302, train error 0.00,  val loss 1.876581, percent error 33.78
# Epoch    48, train loss 0.002265, train error 0.00,  val loss 1.881468, percent error 33.85
# Epoch    49, train loss 0.002228, train error 0.00,  val loss 1.884287, percent error 33.78
# Epoch    50, train loss 0.002195, train error 0.00,  val loss 1.887857, percent error 33.78
# Epoch    51, train loss 0.002161, train error 0.00,  val loss 1.891534, percent error 33.85
# Epoch    52, train loss 0.002129, train error 0.00,  val loss 1.894866, percent error 33.72
# Epoch    53, train loss 0.002099, train error 0.00,  val loss 1.898065, percent error 33.78
# Epoch    54, train loss 0.002068, train error 0.00,  val loss 1.902304, percent error 33.80
# Epoch    55, train loss 0.002037, train error 0.00,  val loss 1.905463, percent error 33.70
# Epoch    56, train loss 0.002008, train error 0.00,  val loss 1.908285, percent error 33.68
# Epoch    57, train loss 0.001980, train error 0.00,  val loss 1.911268, percent error 33.72
# Epoch    58, train loss 0.001953, train error 0.00,  val loss 1.914656, percent error 33.70
# Epoch    59, train loss 0.001926, train error 0.00,  val loss 1.917596, percent error 33.80
# Epoch    60, train loss 0.001913, train error 0.00,  val loss 1.919059, percent error 33.80
# Epoch    61, train loss 0.001900, train error 0.00,  val loss 1.920676, percent error 33.82
# Epoch    62, train loss 0.001888, train error 0.00,  val loss 1.922153, percent error 33.82
# Epoch    63, train loss 0.001876, train error 0.00,  val loss 1.923458, percent error 33.82
# Epoch    64, train loss 0.001863, train error 0.00,  val loss 1.925426, percent error 33.85
# Epoch    65, train loss 0.001851, train error 0.00,  val loss 1.927034, percent error 33.80
# Epoch    66, train loss 0.001839, train error 0.00,  val loss 1.928112, percent error 33.82
# Epoch    67, train loss 0.001828, train error 0.00,  val loss 1.929754, percent error 33.80
# Epoch    68, train loss 0.001816, train error 0.00,  val loss 1.931180, percent error 33.82
# Epoch    69, train loss 0.001804, train error 0.00,  val loss 1.932904, percent error 33.80
# Epoch    70, train loss 0.001793, train error 0.00,  val loss 1.934439, percent error 33.80
# Epoch    71, train loss 0.001782, train error 0.00,  val loss 1.935646, percent error 33.82
# Epoch    72, train loss 0.001771, train error 0.00,  val loss 1.936762, percent error 33.88
# Epoch    73, train loss 0.001760, train error 0.00,  val loss 1.938550, percent error 33.82
# Epoch    74, train loss 0.001749, train error 0.00,  val loss 1.939793, percent error 33.85
# Epoch    75, train loss 0.001739, train error 0.00,  val loss 1.941316, percent error 33.85
# Epoch    76, train loss 0.001728, train error 0.00,  val loss 1.942775, percent error 33.85
# Epoch    77, train loss 0.001718, train error 0.00,  val loss 1.944190, percent error 33.88
# Epoch    78, train loss 0.001707, train error 0.00,  val loss 1.945563, percent error 33.85
# Epoch    79, train loss 0.001697, train error 0.00,  val loss 1.946999, percent error 33.90
# Epoch    80, train loss 0.001692, train error 0.00,  val loss 1.947562, percent error 33.88
# Epoch    81, train loss 0.001687, train error 0.00,  val loss 1.948286, percent error 33.85
# Epoch    82, train loss 0.001682, train error 0.00,  val loss 1.948802, percent error 33.88
# Epoch    83, train loss 0.001677, train error 0.00,  val loss 1.949424, percent error 33.88
# Epoch    84, train loss 0.001672, train error 0.00,  val loss 1.950224, percent error 33.88
# Epoch    85, train loss 0.001667, train error 0.00,  val loss 1.950913, percent error 33.88
# Epoch    86, train loss 0.001663, train error 0.00,  val loss 1.951588, percent error 33.88
# Epoch    87, train loss 0.001658, train error 0.00,  val loss 1.952302, percent error 33.88
# Epoch    88, train loss 0.001653, train error 0.00,  val loss 1.952914, percent error 33.88
# Epoch    89, train loss 0.001648, train error 0.00,  val loss 1.953542, percent error 33.88
# Epoch    90, train loss 0.001644, train error 0.00,  val loss 1.954240, percent error 33.85
# Epoch    91, train loss 0.001639, train error 0.00,  val loss 1.955058, percent error 33.88
# Epoch    92, train loss 0.001634, train error 0.00,  val loss 1.955577, percent error 33.90
# Epoch    93, train loss 0.001629, train error 0.00,  val loss 1.956054, percent error 33.88
# Epoch    94, train loss 0.001625, train error 0.00,  val loss 1.956735, percent error 33.90
# Epoch    95, train loss 0.001620, train error 0.00,  val loss 1.957495, percent error 33.88
# Epoch    96, train loss 0.001616, train error 0.00,  val loss 1.958078, percent error 33.90
# Epoch    97, train loss 0.001611, train error 0.00,  val loss 1.958712, percent error 33.90
# Epoch    98, train loss 0.001607, train error 0.00,  val loss 1.959543, percent error 33.88
# Epoch    99, train loss 0.001602, train error 0.00,  val loss 1.960136, percent error 33.90

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
#
# FOLLOWS BELOW RUNNING WITH THE RESIDUAL CONNECTIONS

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.634590, train error 63.40,  val loss 1.682757, percent error 67.88
# Epoch     1, train loss 1.383926, train error 51.90,  val loss 1.497425, percent error 58.22
# Epoch     2, train loss 1.190313, train error 45.92,  val loss 1.392973, percent error 55.47
# Epoch     3, train loss 1.080920, train error 41.12,  val loss 1.319143, percent error 51.38
# Epoch     4, train loss 0.912188, train error 34.72,  val loss 1.226923, percent error 46.65
# Epoch     5, train loss 0.816326, train error 29.65,  val loss 1.232242, percent error 47.05
# Epoch     6, train loss 0.676119, train error 23.43,  val loss 1.151684, percent error 43.60
# Epoch     7, train loss 0.605368, train error 21.43,  val loss 1.152678, percent error 42.00
# Epoch     8, train loss 0.503367, train error 17.78,  val loss 1.125262, percent error 38.42
# Epoch     9, train loss 0.422733, train error 14.85,  val loss 1.149199, percent error 38.22
# Epoch    10, train loss 0.334405, train error 10.72,  val loss 1.120836, percent error 37.45
# Epoch    11, train loss 0.326933, train error 11.53,  val loss 1.235893, percent error 39.17
# Epoch    12, train loss 0.275413, train error 9.22,  val loss 1.236596, percent error 37.78
# Epoch    13, train loss 0.211798, train error 6.82,  val loss 1.240077, percent error 35.95
# Epoch    14, train loss 0.158603, train error 4.20,  val loss 1.258800, percent error 35.30
# Epoch    15, train loss 0.171365, train error 5.43,  val loss 1.352641, percent error 36.28
# Epoch    16, train loss 0.184318, train error 6.32,  val loss 1.414833, percent error 36.35
# Epoch    17, train loss 0.229728, train error 7.47,  val loss 1.496736, percent error 38.83
# Epoch    18, train loss 0.201202, train error 6.93,  val loss 1.483408, percent error 37.05
# Epoch    19, train loss 0.089085, train error 2.43,  val loss 1.411459, percent error 34.18
# Epoch    20, train loss 0.030504, train error 0.15,  val loss 1.337822, percent error 32.68
# Epoch    21, train loss 0.015677, train error 0.00,  val loss 1.354780, percent error 32.45
# Epoch    22, train loss 0.011395, train error 0.00,  val loss 1.382419, percent error 32.70
# Epoch    23, train loss 0.009403, train error 0.00,  val loss 1.409760, percent error 32.43
# Epoch    24, train loss 0.008086, train error 0.00,  val loss 1.428858, percent error 31.85
# Epoch    25, train loss 0.007144, train error 0.00,  val loss 1.444336, percent error 32.25
# Epoch    26, train loss 0.006469, train error 0.00,  val loss 1.463249, percent error 32.07
# Epoch    27, train loss 0.005902, train error 0.00,  val loss 1.478175, percent error 32.22
# Epoch    28, train loss 0.005462, train error 0.00,  val loss 1.496389, percent error 32.43
# Epoch    29, train loss 0.005029, train error 0.00,  val loss 1.507751, percent error 32.12
# Epoch    30, train loss 0.004717, train error 0.00,  val loss 1.519467, percent error 32.22
# Epoch    31, train loss 0.004372, train error 0.00,  val loss 1.530822, percent error 32.10
# Epoch    32, train loss 0.004116, train error 0.00,  val loss 1.543879, percent error 32.35
# Epoch    33, train loss 0.003898, train error 0.00,  val loss 1.552850, percent error 32.15
# Epoch    34, train loss 0.003685, train error 0.00,  val loss 1.562381, percent error 32.15
# Epoch    35, train loss 0.003496, train error 0.00,  val loss 1.571559, percent error 32.18
# Epoch    36, train loss 0.003329, train error 0.00,  val loss 1.580396, percent error 32.20
# Epoch    37, train loss 0.003179, train error 0.00,  val loss 1.588980, percent error 32.32
# Epoch    38, train loss 0.003041, train error 0.00,  val loss 1.597931, percent error 32.30
# Epoch    39, train loss 0.002925, train error 0.00,  val loss 1.605906, percent error 32.18
# Epoch    40, train loss 0.002852, train error 0.00,  val loss 1.609267, percent error 32.22
# Epoch    41, train loss 0.002794, train error 0.00,  val loss 1.613231, percent error 32.12
# Epoch    42, train loss 0.002742, train error 0.00,  val loss 1.616904, percent error 32.07
# Epoch    43, train loss 0.002689, train error 0.00,  val loss 1.620942, percent error 32.05
# Epoch    44, train loss 0.002639, train error 0.00,  val loss 1.624252, percent error 32.12
# Epoch    45, train loss 0.002591, train error 0.00,  val loss 1.627779, percent error 32.15
# Epoch    46, train loss 0.002546, train error 0.00,  val loss 1.630914, percent error 32.12
# Epoch    47, train loss 0.002500, train error 0.00,  val loss 1.634436, percent error 32.20
# Epoch    48, train loss 0.002457, train error 0.00,  val loss 1.637662, percent error 32.15
# Epoch    49, train loss 0.002415, train error 0.00,  val loss 1.640976, percent error 32.25
# Epoch    50, train loss 0.002374, train error 0.00,  val loss 1.644435, percent error 32.20
# Epoch    51, train loss 0.002335, train error 0.00,  val loss 1.647722, percent error 32.15
# Epoch    52, train loss 0.002298, train error 0.00,  val loss 1.650347, percent error 32.20
# Epoch    53, train loss 0.002261, train error 0.00,  val loss 1.653870, percent error 32.18
# Epoch    54, train loss 0.002225, train error 0.00,  val loss 1.657106, percent error 32.20
# Epoch    55, train loss 0.002191, train error 0.00,  val loss 1.659680, percent error 32.20
# Epoch    56, train loss 0.002157, train error 0.00,  val loss 1.662712, percent error 32.25
# Epoch    57, train loss 0.002125, train error 0.00,  val loss 1.666210, percent error 32.22
# Epoch    58, train loss 0.002093, train error 0.00,  val loss 1.668869, percent error 32.25
# Epoch    59, train loss 0.002063, train error 0.00,  val loss 1.670993, percent error 32.32
# Epoch    60, train loss 0.002047, train error 0.00,  val loss 1.672819, percent error 32.32
# Epoch    61, train loss 0.002033, train error 0.00,  val loss 1.674425, percent error 32.30
# Epoch    62, train loss 0.002018, train error 0.00,  val loss 1.675690, percent error 32.30
# Epoch    63, train loss 0.002004, train error 0.00,  val loss 1.677104, percent error 32.35
# Epoch    64, train loss 0.001990, train error 0.00,  val loss 1.678565, percent error 32.32
# Epoch    65, train loss 0.001976, train error 0.00,  val loss 1.679830, percent error 32.32
# Epoch    66, train loss 0.001962, train error 0.00,  val loss 1.681286, percent error 32.28
# Epoch    67, train loss 0.001948, train error 0.00,  val loss 1.682735, percent error 32.32
# Epoch    68, train loss 0.001935, train error 0.00,  val loss 1.683799, percent error 32.30
# Epoch    69, train loss 0.001922, train error 0.00,  val loss 1.685286, percent error 32.30
# Epoch    70, train loss 0.001909, train error 0.00,  val loss 1.686566, percent error 32.35
# Epoch    71, train loss 0.001896, train error 0.00,  val loss 1.687899, percent error 32.25
# Epoch    72, train loss 0.001883, train error 0.00,  val loss 1.689469, percent error 32.28
# Epoch    73, train loss 0.001871, train error 0.00,  val loss 1.690663, percent error 32.28
# Epoch    74, train loss 0.001859, train error 0.00,  val loss 1.691706, percent error 32.30
# Epoch    75, train loss 0.001846, train error 0.00,  val loss 1.692927, percent error 32.28
# Epoch    76, train loss 0.001834, train error 0.00,  val loss 1.694239, percent error 32.30
# Epoch    77, train loss 0.001823, train error 0.00,  val loss 1.695487, percent error 32.22
# Epoch    78, train loss 0.001811, train error 0.00,  val loss 1.697083, percent error 32.20
# Epoch    79, train loss 0.001800, train error 0.00,  val loss 1.698370, percent error 32.22
# Epoch    80, train loss 0.001794, train error 0.00,  val loss 1.698908, percent error 32.22
# Epoch    81, train loss 0.001788, train error 0.00,  val loss 1.699565, percent error 32.22
# Epoch    82, train loss 0.001782, train error 0.00,  val loss 1.700089, percent error 32.25
# Epoch    83, train loss 0.001777, train error 0.00,  val loss 1.700781, percent error 32.20
# Epoch    84, train loss 0.001771, train error 0.00,  val loss 1.701477, percent error 32.22
# Epoch    85, train loss 0.001766, train error 0.00,  val loss 1.702005, percent error 32.25
# Epoch    86, train loss 0.001760, train error 0.00,  val loss 1.702538, percent error 32.22
# Epoch    87, train loss 0.001755, train error 0.00,  val loss 1.703085, percent error 32.20
# Epoch    88, train loss 0.001749, train error 0.00,  val loss 1.703910, percent error 32.25
# Epoch    89, train loss 0.001744, train error 0.00,  val loss 1.704527, percent error 32.25
# Epoch    90, train loss 0.001738, train error 0.00,  val loss 1.705184, percent error 32.25
# Epoch    91, train loss 0.001733, train error 0.00,  val loss 1.705631, percent error 32.22
# Epoch    92, train loss 0.001728, train error 0.00,  val loss 1.706276, percent error 32.25
# Epoch    93, train loss 0.001722, train error 0.00,  val loss 1.706880, percent error 32.22
# Epoch    94, train loss 0.001717, train error 0.00,  val loss 1.707459, percent error 32.20
# Epoch    95, train loss 0.001712, train error 0.00,  val loss 1.707969, percent error 32.22
# Epoch    96, train loss 0.001707, train error 0.00,  val loss 1.708670, percent error 32.25
# Epoch    97, train loss 0.001702, train error 0.00,  val loss 1.709312, percent error 32.28
# Epoch    98, train loss 0.001697, train error 0.00,  val loss 1.709936, percent error 32.20
# Epoch    99, train loss 0.001691, train error 0.00,  val loss 1.710365, percent error 32.22

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ou seja, melhora um pouco o erro de validação, e oscila menos o erro de treinamento até zerar na mesma época
