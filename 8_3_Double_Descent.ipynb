# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# fatal: destination path 'mnist1d' already exists and is not an empty directory.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.284067, train error 87.78,  test loss 2.277310, test error 87.00
# Epoch   100, train loss 1.933583, train error 71.95,  test loss 1.777729, test error 69.88
# Epoch   200, train loss 1.908544, train error 70.78,  test loss 1.743871, test error 68.40
# Epoch   300, train loss 1.891583, train error 69.97,  test loss 1.726063, test error 68.45
# Epoch   400, train loss 1.873064, train error 69.82,  test loss 1.704744, test error 68.20
# Epoch   500, train loss 1.865187, train error 69.88,  test loss 1.698015, test error 67.88
# Epoch   600, train loss 1.863607, train error 70.05,  test loss 1.697033, test error 67.07
# Epoch   700, train loss 1.870946, train error 70.03,  test loss 1.719891, test error 68.05
# Epoch   800, train loss 1.861771, train error 69.97,  test loss 1.693645, test error 67.43
# Epoch   900, train loss 1.863570, train error 70.18,  test loss 1.699463, test error 67.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.298470, train error 86.90,  test loss 2.293573, test error 87.53
# Epoch   100, train loss 1.847900, train error 69.45,  test loss 1.701028, test error 68.68
# Epoch   200, train loss 1.837565, train error 68.80,  test loss 1.706521, test error 68.05
# Epoch   300, train loss 1.834069, train error 69.00,  test loss 1.711695, test error 68.55
# Epoch   400, train loss 1.825725, train error 68.97,  test loss 1.712554, test error 68.15
# Epoch   500, train loss 1.823975, train error 69.15,  test loss 1.726492, test error 68.45
# Epoch   600, train loss 1.823162, train error 68.43,  test loss 1.726221, test error 68.25
# Epoch   700, train loss 1.821806, train error 68.78,  test loss 1.732840, test error 68.62
# Epoch   800, train loss 1.822702, train error 68.43,  test loss 1.724759, test error 68.55
# Epoch   900, train loss 1.820660, train error 69.12,  test loss 1.737057, test error 68.40
# Training model with   6 hidden variables
# Epoch     0, train loss 2.288161, train error 87.60,  test loss 2.283998, test error 88.95
# Epoch   100, train loss 1.724096, train error 61.12,  test loss 1.514643, test error 57.47
# Epoch   200, train loss 1.707557, train error 60.17,  test loss 1.501509, test error 58.12
# Epoch   300, train loss 1.689869, train error 58.80,  test loss 1.479864, test error 57.53
# Epoch   400, train loss 1.683426, train error 59.33,  test loss 1.488109, test error 57.12
# Epoch   500, train loss 1.680463, train error 59.47,  test loss 1.494872, test error 57.55
# Epoch   600, train loss 1.680808, train error 59.50,  test loss 1.505964, test error 58.17
# Epoch   700, train loss 1.673921, train error 58.88,  test loss 1.503132, test error 57.40
# Epoch   800, train loss 1.671605, train error 58.65,  test loss 1.507369, test error 57.60
# Epoch   900, train loss 1.669679, train error 60.15,  test loss 1.504932, test error 57.83
# Training model with   8 hidden variables
# Epoch     0, train loss 2.292479, train error 86.97,  test loss 2.284184, test error 86.93
# Epoch   100, train loss 1.620038, train error 56.47,  test loss 1.433876, test error 55.10
# Epoch   200, train loss 1.576061, train error 55.55,  test loss 1.411744, test error 54.40
# Epoch   300, train loss 1.559072, train error 54.40,  test loss 1.416727, test error 54.12
# Epoch   400, train loss 1.544702, train error 53.85,  test loss 1.408092, test error 53.25
# Epoch   500, train loss 1.542114, train error 54.03,  test loss 1.411411, test error 53.70
# Epoch   600, train loss 1.545133, train error 54.17,  test loss 1.422186, test error 54.33
# Epoch   700, train loss 1.538936, train error 53.62,  test loss 1.422807, test error 54.35
# Epoch   800, train loss 1.532651, train error 52.85,  test loss 1.423858, test error 53.30
# Epoch   900, train loss 1.522206, train error 53.30,  test loss 1.436386, test error 54.38
# Training model with  10 hidden variables
# Epoch     0, train loss 2.270144, train error 86.70,  test loss 2.268969, test error 87.18
# Epoch   100, train loss 1.495255, train error 50.28,  test loss 1.314309, test error 48.30
# Epoch   200, train loss 1.426311, train error 47.42,  test loss 1.290425, test error 47.97
# Epoch   300, train loss 1.408845, train error 47.15,  test loss 1.293889, test error 48.12
# Epoch   400, train loss 1.393763, train error 46.17,  test loss 1.311401, test error 48.60
# Epoch   500, train loss 1.387657, train error 46.17,  test loss 1.316254, test error 48.35
# Epoch   600, train loss 1.385860, train error 46.38,  test loss 1.321919, test error 48.90
# Epoch   700, train loss 1.372432, train error 46.33,  test loss 1.322377, test error 48.53
# Epoch   800, train loss 1.371894, train error 46.47,  test loss 1.336914, test error 48.65
# Epoch   900, train loss 1.377491, train error 46.28,  test loss 1.353840, test error 48.95
# Training model with  14 hidden variables
# Epoch     0, train loss 2.231837, train error 82.78,  test loss 2.203367, test error 81.35
# Epoch   100, train loss 1.413570, train error 46.45,  test loss 1.282831, test error 46.75
# Epoch   200, train loss 1.352348, train error 44.28,  test loss 1.301095, test error 47.17
# Epoch   300, train loss 1.328771, train error 43.60,  test loss 1.309090, test error 46.35
# Epoch   400, train loss 1.315367, train error 43.25,  test loss 1.327139, test error 46.40
# Epoch   500, train loss 1.310631, train error 42.88,  test loss 1.331843, test error 47.03
# Epoch   600, train loss 1.308661, train error 43.72,  test loss 1.348752, test error 48.00
# Epoch   700, train loss 1.302674, train error 42.50,  test loss 1.342878, test error 47.33
# Epoch   800, train loss 1.296489, train error 42.78,  test loss 1.366192, test error 48.22
# Epoch   900, train loss 1.283741, train error 42.80,  test loss 1.363630, test error 48.17
# Training model with  18 hidden variables
# Epoch     0, train loss 2.264984, train error 83.72,  test loss 2.244499, test error 83.32
# Epoch   100, train loss 1.337306, train error 43.45,  test loss 1.283893, test error 47.05
# Epoch   200, train loss 1.260417, train error 41.30,  test loss 1.318549, test error 48.42
# Epoch   300, train loss 1.222542, train error 40.95,  test loss 1.370840, test error 48.53
# Epoch   400, train loss 1.191775, train error 39.38,  test loss 1.387771, test error 48.90
# Epoch   500, train loss 1.181969, train error 39.60,  test loss 1.406258, test error 49.47
# Epoch   600, train loss 1.165586, train error 39.25,  test loss 1.435100, test error 50.53
# Epoch   700, train loss 1.157111, train error 38.70,  test loss 1.439198, test error 50.22
# Epoch   800, train loss 1.152126, train error 39.22,  test loss 1.453162, test error 50.00
# Epoch   900, train loss 1.143561, train error 38.35,  test loss 1.477401, test error 50.15
# Training model with  22 hidden variables
# Epoch     0, train loss 2.124423, train error 78.30,  test loss 2.063214, test error 76.12
# Epoch   100, train loss 1.296630, train error 43.03,  test loss 1.339764, test error 49.40
# Epoch   200, train loss 1.167963, train error 39.30,  test loss 1.360316, test error 48.75
# Epoch   300, train loss 1.120188, train error 37.92,  test loss 1.436599, test error 49.65
# Epoch   400, train loss 1.083722, train error 36.78,  test loss 1.478599, test error 50.30
# Epoch   500, train loss 1.082376, train error 36.85,  test loss 1.515554, test error 50.75
# Epoch   600, train loss 1.047350, train error 35.20,  test loss 1.571029, test error 51.62
# Epoch   700, train loss 1.036445, train error 35.10,  test loss 1.616939, test error 51.72
# Epoch   800, train loss 1.025606, train error 34.65,  test loss 1.624211, test error 51.92
# Epoch   900, train loss 1.024766, train error 34.75,  test loss 1.662785, test error 51.22
# Training model with  26 hidden variables
# Epoch     0, train loss 2.120280, train error 78.57,  test loss 2.050268, test error 76.88
# Epoch   100, train loss 1.225442, train error 41.17,  test loss 1.356803, test error 49.47
# Epoch   200, train loss 1.072284, train error 35.68,  test loss 1.455442, test error 49.83
# Epoch   300, train loss 0.997233, train error 33.85,  test loss 1.581451, test error 50.85
# Epoch   400, train loss 0.943105, train error 32.10,  test loss 1.662727, test error 51.97
# Epoch   500, train loss 0.916161, train error 30.82,  test loss 1.748353, test error 53.12
# Epoch   600, train loss 0.898836, train error 31.07,  test loss 1.820517, test error 53.17
# Epoch   700, train loss 0.863964, train error 30.00,  test loss 1.887860, test error 54.20
# Epoch   800, train loss 0.879778, train error 30.88,  test loss 1.937006, test error 53.60
# Epoch   900, train loss 0.845955, train error 29.47,  test loss 1.946940, test error 53.75
# Training model with  30 hidden variables
# Epoch     0, train loss 2.180151, train error 80.43,  test loss 2.156071, test error 79.93
# Epoch   100, train loss 1.131296, train error 38.17,  test loss 1.333685, test error 47.50
# Epoch   200, train loss 0.955019, train error 31.90,  test loss 1.530355, test error 50.70
# Epoch   300, train loss 0.856893, train error 29.10,  test loss 1.742892, test error 52.67
# Epoch   400, train loss 0.789506, train error 26.15,  test loss 1.878614, test error 51.33
# Epoch   500, train loss 0.743237, train error 25.15,  test loss 2.068273, test error 53.22
# Epoch   600, train loss 0.724374, train error 23.82,  test loss 2.188775, test error 54.05
# Epoch   700, train loss 0.718627, train error 24.68,  test loss 2.322055, test error 54.83
# Epoch   800, train loss 0.673512, train error 23.00,  test loss 2.452816, test error 55.78
# Epoch   900, train loss 0.654294, train error 22.00,  test loss 2.563642, test error 55.85
# Training model with  35 hidden variables
# Epoch     0, train loss 2.077199, train error 78.18,  test loss 1.998120, test error 76.68
# Epoch   100, train loss 1.001097, train error 32.82,  test loss 1.367387, test error 48.22
# Epoch   200, train loss 0.798961, train error 27.03,  test loss 1.731714, test error 52.60
# Epoch   300, train loss 0.685953, train error 22.50,  test loss 2.062146, test error 53.30
# Epoch   400, train loss 0.637058, train error 21.68,  test loss 2.404185, test error 55.17
# Epoch   500, train loss 0.579645, train error 20.15,  test loss 2.732207, test error 54.05
# Epoch   600, train loss 0.580988, train error 20.68,  test loss 3.203085, test error 57.20
# Epoch   700, train loss 0.495745, train error 17.47,  test loss 3.514645, test error 57.33
# Epoch   800, train loss 0.504263, train error 18.15,  test loss 3.828546, test error 56.50
# Epoch   900, train loss 0.464745, train error 17.07,  test loss 4.141590, test error 56.58
# Training model with  40 hidden variables
# Epoch     0, train loss 2.182446, train error 81.18,  test loss 2.161969, test error 80.05
# Epoch   100, train loss 0.975473, train error 31.50,  test loss 1.380269, test error 48.25
# Epoch   200, train loss 0.733929, train error 24.95,  test loss 1.779037, test error 51.72
# Epoch   300, train loss 0.564616, train error 18.62,  test loss 2.291854, test error 54.05
# Epoch   400, train loss 0.470231, train error 15.50,  test loss 2.819701, test error 53.95
# Epoch   500, train loss 0.403112, train error 13.53,  test loss 3.457754, test error 55.67
# Epoch   600, train loss 0.354222, train error 12.82,  test loss 4.063753, test error 55.53
# Epoch   700, train loss 0.386436, train error 14.93,  test loss 4.679933, test error 56.58
# Epoch   800, train loss 0.326869, train error 11.97,  test loss 5.350597, test error 57.70
# Epoch   900, train loss 0.328491, train error 12.57,  test loss 5.749048, test error 57.05
# Training model with  45 hidden variables
# Epoch     0, train loss 2.105928, train error 78.28,  test loss 2.039432, test error 76.10
# Epoch   100, train loss 0.829634, train error 26.70,  test loss 1.525654, test error 49.20
# Epoch   200, train loss 0.486872, train error 15.22,  test loss 2.297725, test error 53.00
# Epoch   300, train loss 0.301594, train error 9.45,  test loss 3.400259, test error 55.10
# Epoch   400, train loss 0.209725, train error 7.18,  test loss 4.728584, test error 56.58
# Epoch   500, train loss 0.143363, train error 4.70,  test loss 6.084603, test error 56.78
# Epoch   600, train loss 0.101460, train error 3.12,  test loss 7.289983, test error 56.72
# Epoch   700, train loss 0.013280, train error 0.00,  test loss 8.344522, test error 57.30
# Epoch   800, train loss 0.008818, train error 0.00,  test loss 9.063892, test error 57.20
# Epoch   900, train loss 0.006529, train error 0.00,  test loss 9.578940, test error 57.15
# Training model with  50 hidden variables
# Epoch     0, train loss 2.071906, train error 78.78,  test loss 2.027515, test error 78.57
# Epoch   100, train loss 0.738688, train error 23.32,  test loss 1.634103, test error 52.08
# Epoch   200, train loss 0.380691, train error 12.00,  test loss 2.568091, test error 53.20
# Epoch   300, train loss 0.200522, train error 5.85,  test loss 3.938409, test error 54.97
# Epoch   400, train loss 0.097185, train error 2.35,  test loss 5.611215, test error 56.03
# Epoch   500, train loss 0.015123, train error 0.00,  test loss 6.828135, test error 55.97
# Epoch   600, train loss 0.009243, train error 0.00,  test loss 7.552479, test error 56.00
# Epoch   700, train loss 0.006569, train error 0.00,  test loss 8.077256, test error 56.03
# Epoch   800, train loss 0.004977, train error 0.00,  test loss 8.481397, test error 55.97
# Epoch   900, train loss 0.003969, train error 0.00,  test loss 8.824440, test error 56.17
# Training model with  55 hidden variables
# Epoch     0, train loss 2.038125, train error 76.25,  test loss 1.961706, test error 75.70
# Epoch   100, train loss 0.621677, train error 19.12,  test loss 1.761988, test error 53.15
# Epoch   200, train loss 0.232142, train error 6.43,  test loss 3.165757, test error 54.65
# Epoch   300, train loss 0.039130, train error 0.05,  test loss 4.909020, test error 55.83
# Epoch   400, train loss 0.013624, train error 0.00,  test loss 5.959335, test error 55.62
# Epoch   500, train loss 0.007996, train error 0.00,  test loss 6.587038, test error 55.62
# Epoch   600, train loss 0.005415, train error 0.00,  test loss 7.027545, test error 55.62
# Epoch   700, train loss 0.004101, train error 0.00,  test loss 7.374845, test error 55.67
# Epoch   800, train loss 0.003245, train error 0.00,  test loss 7.653416, test error 55.53
# Epoch   900, train loss 0.002687, train error 0.00,  test loss 7.889060, test error 55.55
# Training model with  60 hidden variables
# Epoch     0, train loss 2.095387, train error 78.20,  test loss 2.056504, test error 78.05
# Epoch   100, train loss 0.572922, train error 17.90,  test loss 1.813635, test error 52.17
# Epoch   200, train loss 0.105266, train error 1.12,  test loss 3.550033, test error 55.35
# Epoch   300, train loss 0.018890, train error 0.00,  test loss 4.992330, test error 55.90
# Epoch   400, train loss 0.009225, train error 0.00,  test loss 5.688747, test error 55.33
# Epoch   500, train loss 0.005799, train error 0.00,  test loss 6.155266, test error 55.53
# Epoch   600, train loss 0.004168, train error 0.00,  test loss 6.500660, test error 55.78
# Epoch   700, train loss 0.003194, train error 0.00,  test loss 6.773874, test error 55.83
# Epoch   800, train loss 0.002563, train error 0.00,  test loss 7.004352, test error 55.83
# Epoch   900, train loss 0.002130, train error 0.00,  test loss 7.196253, test error 55.95
# Training model with  70 hidden variables
# Epoch     0, train loss 2.029333, train error 74.30,  test loss 1.956645, test error 74.70
# Epoch   100, train loss 0.359442, train error 8.43,  test loss 1.961734, test error 51.92
# Epoch   200, train loss 0.031708, train error 0.00,  test loss 3.595840, test error 53.85
# Epoch   300, train loss 0.010545, train error 0.00,  test loss 4.364412, test error 54.20
# Epoch   400, train loss 0.005955, train error 0.00,  test loss 4.791876, test error 54.58
# Epoch   500, train loss 0.003999, train error 0.00,  test loss 5.086621, test error 54.45
# Epoch   600, train loss 0.002960, train error 0.00,  test loss 5.308337, test error 54.53
# Epoch   700, train loss 0.002325, train error 0.00,  test loss 5.492600, test error 54.60
# Epoch   800, train loss 0.001901, train error 0.00,  test loss 5.643390, test error 54.67
# Epoch   900, train loss 0.001601, train error 0.00,  test loss 5.772954, test error 54.72
# Training model with  80 hidden variables
# Epoch     0, train loss 2.024249, train error 75.18,  test loss 1.962068, test error 75.28
# Epoch   100, train loss 0.253238, train error 5.03,  test loss 2.195294, test error 53.55
# Epoch   200, train loss 0.019616, train error 0.00,  test loss 3.603980, test error 53.85
# Epoch   300, train loss 0.007890, train error 0.00,  test loss 4.196555, test error 54.10
# Epoch   400, train loss 0.004713, train error 0.00,  test loss 4.547346, test error 54.28
# Epoch   500, train loss 0.003240, train error 0.00,  test loss 4.791638, test error 54.30
# Epoch   600, train loss 0.002439, train error 0.00,  test loss 4.984673, test error 54.42
# Epoch   700, train loss 0.001935, train error 0.00,  test loss 5.139268, test error 54.40
# Epoch   800, train loss 0.001595, train error 0.00,  test loss 5.272435, test error 54.45
# Epoch   900, train loss 0.001350, train error 0.00,  test loss 5.384088, test error 54.40
# Training model with  90 hidden variables
# Epoch     0, train loss 2.038559, train error 74.88,  test loss 1.982026, test error 75.15
# Epoch   100, train loss 0.150956, train error 1.15,  test loss 2.110925, test error 50.88
# Epoch   200, train loss 0.014988, train error 0.00,  test loss 3.116167, test error 51.58
# Epoch   300, train loss 0.006528, train error 0.00,  test loss 3.535683, test error 51.38
# Epoch   400, train loss 0.003987, train error 0.00,  test loss 3.792001, test error 51.62
# Epoch   500, train loss 0.002802, train error 0.00,  test loss 3.973710, test error 51.47
# Epoch   600, train loss 0.002130, train error 0.00,  test loss 4.116909, test error 51.38
# Epoch   700, train loss 0.001704, train error 0.00,  test loss 4.237275, test error 51.42
# Epoch   800, train loss 0.001411, train error 0.00,  test loss 4.334851, test error 51.38
# Epoch   900, train loss 0.001199, train error 0.00,  test loss 4.421738, test error 51.40
# Training model with 100 hidden variables
# Epoch     0, train loss 1.973336, train error 73.43,  test loss 1.895391, test error 73.20
# Epoch   100, train loss 0.091706, train error 0.20,  test loss 2.399657, test error 52.70
# Epoch   200, train loss 0.012114, train error 0.00,  test loss 3.309239, test error 52.22
# Epoch   300, train loss 0.005680, train error 0.00,  test loss 3.697604, test error 52.55
# Epoch   400, train loss 0.003556, train error 0.00,  test loss 3.936531, test error 52.53
# Epoch   500, train loss 0.002533, train error 0.00,  test loss 4.111006, test error 52.42
# Epoch   600, train loss 0.001944, train error 0.00,  test loss 4.250284, test error 52.60
# Epoch   700, train loss 0.001565, train error 0.00,  test loss 4.363879, test error 52.62
# Epoch   800, train loss 0.001301, train error 0.00,  test loss 4.460670, test error 52.65
# Epoch   900, train loss 0.001108, train error 0.00,  test loss 4.544086, test error 52.60
# Training model with 120 hidden variables
# Epoch     0, train loss 2.021191, train error 75.28,  test loss 1.910619, test error 74.40
# Epoch   100, train loss 0.050233, train error 0.00,  test loss 2.310221, test error 50.88
# Epoch   200, train loss 0.009381, train error 0.00,  test loss 2.972605, test error 51.62
# Epoch   300, train loss 0.004620, train error 0.00,  test loss 3.263050, test error 51.35
# Epoch   400, train loss 0.002957, train error 0.00,  test loss 3.454806, test error 51.35
# Epoch   500, train loss 0.002131, train error 0.00,  test loss 3.594535, test error 51.40
# Epoch   600, train loss 0.001646, train error 0.00,  test loss 3.704802, test error 51.53
# Epoch   700, train loss 0.001331, train error 0.00,  test loss 3.796715, test error 51.53
# Epoch   800, train loss 0.001111, train error 0.00,  test loss 3.874020, test error 51.53
# Epoch   900, train loss 0.000949, train error 0.00,  test loss 3.941729, test error 51.55
# Training model with 140 hidden variables
# Epoch     0, train loss 2.004460, train error 74.50,  test loss 1.935798, test error 75.20
# Epoch   100, train loss 0.034530, train error 0.00,  test loss 2.174318, test error 49.60
# Epoch   200, train loss 0.007870, train error 0.00,  test loss 2.651153, test error 49.10
# Epoch   300, train loss 0.004058, train error 0.00,  test loss 2.882316, test error 49.20
# Epoch   400, train loss 0.002643, train error 0.00,  test loss 3.033208, test error 49.35
# Epoch   500, train loss 0.001925, train error 0.00,  test loss 3.145636, test error 49.47
# Epoch   600, train loss 0.001497, train error 0.00,  test loss 3.234560, test error 49.55
# Epoch   700, train loss 0.001216, train error 0.00,  test loss 3.308715, test error 49.50
# Epoch   800, train loss 0.001019, train error 0.00,  test loss 3.372258, test error 49.50
# Epoch   900, train loss 0.000873, train error 0.00,  test loss 3.427930, test error 49.58
# Training model with 160 hidden variables
# Epoch     0, train loss 1.936767, train error 72.05,  test loss 1.848876, test error 71.22
# Epoch   100, train loss 0.028981, train error 0.00,  test loss 2.234380, test error 50.35
# Epoch   200, train loss 0.007267, train error 0.00,  test loss 2.666543, test error 50.00
# Epoch   300, train loss 0.003819, train error 0.00,  test loss 2.887383, test error 50.38
# Epoch   400, train loss 0.002506, train error 0.00,  test loss 3.028866, test error 50.00
# Epoch   500, train loss 0.001833, train error 0.00,  test loss 3.134334, test error 50.15
# Epoch   600, train loss 0.001431, train error 0.00,  test loss 3.221941, test error 50.22
# Epoch   700, train loss 0.001166, train error 0.00,  test loss 3.292341, test error 50.30
# Epoch   800, train loss 0.000978, train error 0.00,  test loss 3.352952, test error 50.30
# Epoch   900, train loss 0.000840, train error 0.00,  test loss 3.406256, test error 50.38
# Training model with 180 hidden variables
# Epoch     0, train loss 1.923950, train error 70.72,  test loss 1.848361, test error 71.10
# Epoch   100, train loss 0.024288, train error 0.00,  test loss 2.116410, test error 50.33
# Epoch   200, train loss 0.006607, train error 0.00,  test loss 2.480283, test error 50.15
# Epoch   300, train loss 0.003540, train error 0.00,  test loss 2.665876, test error 49.85
# Epoch   400, train loss 0.002342, train error 0.00,  test loss 2.787302, test error 49.92
# Epoch   500, train loss 0.001725, train error 0.00,  test loss 2.879839, test error 49.88
# Epoch   600, train loss 0.001351, train error 0.00,  test loss 2.953100, test error 49.92
# Epoch   700, train loss 0.001103, train error 0.00,  test loss 3.014608, test error 49.90
# Epoch   800, train loss 0.000927, train error 0.00,  test loss 3.067371, test error 49.90
# Epoch   900, train loss 0.000797, train error 0.00,  test loss 3.113647, test error 50.00
# Training model with 200 hidden variables
# Epoch     0, train loss 1.907609, train error 70.15,  test loss 1.837782, test error 71.68
# Epoch   100, train loss 0.020520, train error 0.00,  test loss 2.141304, test error 49.30
# Epoch   200, train loss 0.005934, train error 0.00,  test loss 2.469191, test error 49.33
# Epoch   300, train loss 0.003233, train error 0.00,  test loss 2.642572, test error 49.35
# Epoch   400, train loss 0.002165, train error 0.00,  test loss 2.756375, test error 49.22
# Epoch   500, train loss 0.001603, train error 0.00,  test loss 2.843364, test error 49.25
# Epoch   600, train loss 0.001261, train error 0.00,  test loss 2.913235, test error 49.25
# Epoch   700, train loss 0.001033, train error 0.00,  test loss 2.971171, test error 49.22
# Epoch   800, train loss 0.000870, train error 0.00,  test loss 3.020990, test error 49.25
# Epoch   900, train loss 0.000749, train error 0.00,  test loss 3.064714, test error 49.22
# Training model with 250 hidden variables
# Epoch     0, train loss 1.906608, train error 69.82,  test loss 1.816124, test error 69.82
# Epoch   100, train loss 0.016923, train error 0.00,  test loss 1.943297, test error 48.42
# Epoch   200, train loss 0.005303, train error 0.00,  test loss 2.203620, test error 48.08
# Epoch   300, train loss 0.002960, train error 0.00,  test loss 2.342113, test error 48.10
# Epoch   400, train loss 0.001998, train error 0.00,  test loss 2.436552, test error 48.00
# Epoch   500, train loss 0.001487, train error 0.00,  test loss 2.508061, test error 47.97
# Epoch   600, train loss 0.001174, train error 0.00,  test loss 2.565514, test error 48.00
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.613740, test error 47.92
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.655354, test error 47.90
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.692030, test error 47.83
# Training model with 300 hidden variables
# Epoch     0, train loss 1.915165, train error 70.78,  test loss 1.849601, test error 72.20
# Epoch   100, train loss 0.014389, train error 0.00,  test loss 1.932179, test error 47.78
# Epoch   200, train loss 0.004807, train error 0.00,  test loss 2.165178, test error 47.72
# Epoch   300, train loss 0.002724, train error 0.00,  test loss 2.293886, test error 47.50
# Epoch   400, train loss 0.001855, train error 0.00,  test loss 2.380485, test error 47.42
# Epoch   500, train loss 0.001388, train error 0.00,  test loss 2.447927, test error 47.53
# Epoch   600, train loss 0.001100, train error 0.00,  test loss 2.502192, test error 47.47
# Epoch   700, train loss 0.000906, train error 0.00,  test loss 2.547436, test error 47.50
# Epoch   800, train loss 0.000767, train error 0.00,  test loss 2.586699, test error 47.55
# Epoch   900, train loss 0.000663, train error 0.00,  test loss 2.620920, test error 47.58
# Training model with 400 hidden variables
# Epoch     0, train loss 1.832632, train error 64.68,  test loss 1.759739, test error 67.25
# Epoch   100, train loss 0.011517, train error 0.00,  test loss 1.821894, test error 46.85
# Epoch   200, train loss 0.004124, train error 0.00,  test loss 2.005035, test error 47.03
# Epoch   300, train loss 0.002390, train error 0.00,  test loss 2.108505, test error 47.00
# Epoch   400, train loss 0.001648, train error 0.00,  test loss 2.180736, test error 46.85
# Epoch   500, train loss 0.001242, train error 0.00,  test loss 2.235274, test error 46.67
# Epoch   600, train loss 0.000989, train error 0.00,  test loss 2.278596, test error 46.67
# Epoch   700, train loss 0.000818, train error 0.00,  test loss 2.315453, test error 46.72
# Epoch   800, train loss 0.000694, train error 0.00,  test loss 2.347719, test error 46.72
# Epoch   900, train loss 0.000601, train error 0.00,  test loss 2.375670, test error 46.67

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
